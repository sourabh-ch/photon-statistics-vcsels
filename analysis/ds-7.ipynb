# %%
import os
import numpy as np

import pandas as pd

from scipy import stats
from scipy.interpolate import interp1d

import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')

import pandas as pd
import glob
import natsort

import ipywidgets as widgets
from ipywidgets import interact, interact_manual

from RSRTxReadBin import RTxReadBin
# Out:
# /var/folders/hg/n17fww195g9887twwb23k9k40000gn/T/ipykernel_19409/3193881200.py:12: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg')

# %%
path = 'data-sets/data-set-7'
ds7_files = natsort.natsorted(glob.glob(path+ '/*.Wfm.bin'))

# %%
def ds11_stats(file):
    y, x, S = RTxReadBin(file)
    return y, x, S

# %%
test_y, test_x, test_S = ds11_stats(ds7_files[10])

# %%
plt.plot(test_x,test_y.flat)

# %%
print(test_S)
# Out:
# {'SourceType': 'eRS_SIGNAL_SOURCE_TYPE_SOURCE', 'Resolution': 2e-11, 'RecordLength': 10000000.0, 'HWRecordLength': 10000000.0, 'TriggerOffset': 0.0, 'RescaleCenterTime': -5e-06, 'DecimationMode': 'eRS_DECIMATION_MODE_SAMPLE', 'TraceArithmetics': 'eRS_TRACE_ARITHMETICS_SINGLE', 'TraceType': 'eRS_TRACE_TYPE_NORMAL', 'BaseUnit': 'eRS_UNIT_LEVEL_V', 'BaseUnitRelative': 'eRS_ONOFF_OFF', 'Impedance': 50.0, 'XStart': -0.000105, 'XStop': 9.5e-05, 'SignalRecordLength': 10000000.0, 'HardwareXStart': -0.00010500076, 'HardwareXStop': 9.50008e-05, 'SignalHardwareRecordLength': 10000078.0, 'AdjustedResolutionBW': 0.0, 'NoiseBandwidth': 0.0, 'InterleavedTraceCount': 1.0, 'ValueType': 'eRS_SIGNAL_VALUE_TYPE_COMPLETELY_FINITE_DEFINED', 'NofQuantisationLevels': 64768.0, 'DecimationFactor': 1.0, 'TOADone': 'eRS_ONOFF_ON', 'ISO_TRG': 0.0, 'SC_POST': 0.0, 'SC_TRG': 0.0, 'SignalResolution': 2e-11, 'LeadingSettlingSamples': 38.0, 'TimeScale': 2e-05, 'ReferencePoint': 52.5, 'RescaleCenterPoint': 50.0, 'Vert
# ...
